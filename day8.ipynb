# %% [markdown]
# Importing Required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Dataset

# %%
import pandas as pd
df = pd.read_csv("data.csv",encoding="latin")
print(df.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12-01-2010 08:26       2.55     17850.0  United Kingdom
# 1  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 2  12-01-2010 08:26       2.75     17850.0  United Kingdom
# 3  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 4  12-01-2010 08:26       3.39     17850.0  United Kingdom

# %% [markdown]
# Handeling Missing Values

# %%
df["Description"] = df["Description"].fillna("Unknown")

# %%
df["CustomerID"] = df["CustomerID"].fillna("Unknown")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  str
#  1   StockCode    541909 non-null  str
#  2   Description  541909 non-null  str
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  str
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  object
#  7   Country      541909 non-null  str
# dtypes: float64(1), int64(1), object(1), str(5)
# memory usage: 33.1+ MB

# %% [markdown]
# Implementing First Core Feature

# %%
# Feature1 : Create TotalAmount feature
df["TotalAmount"] = df["Quantity"] * df["UnitPrice"]

# Display the first five rows
df[["Quantity", "UnitPrice", "TotalAmount"]].head()
# Out:
#    Quantity  UnitPrice  TotalAmount
# 0         6       2.55        15.30
# 1         6       3.39        20.34
# 2         8       2.75        22.00
# 3         6       3.39        20.34
# 4         6       3.39        20.34

# %% [markdown]
# Verifying the Core Feature

# %%
X = df[["Quantity", "UnitPrice"]]
y = df["TotalAmount"]

print("Features:")
print(X.head())

print("\nTarget:")
print(y.head())
# Out:
# Features:
#    Quantity  UnitPrice
# 0         6       2.55
# 1         6       3.39
# 2         8       2.75
# 3         6       3.39
# 4         6       3.39
#
# Target:
# 0    15.30
# 1    20.34
# 2    22.00
# 3    20.34
# 4    20.34
# Name: TotalAmount, dtype: float64

# %% [markdown]
# Checking for missing Values

# %%
print("Missing values in Quantity:", df["Quantity"].isnull().sum())
print("Missing values in UnitPrice:", df["UnitPrice"].isnull().sum())
# Out:
# Missing values in Quantity: 0
# Missing values in UnitPrice: 0

# %% [markdown]
# Checking for Datatypes

# %%
print(df["Quantity"].dtype)
print(df["UnitPrice"].dtype)
# Out:
# int64
# float64

# %% [markdown]
# The Core Feature Does:

# %%
"""
Core Feature 1:
This feature prepares the E-commerce sales data for analysis.
It handles missing values and creates a new column called
'TotalAmount' by multiplying Quantity and UnitPrice.
This makes it easier to analyze the total value of each transaction.
"""
# Out:
# "\nCore Feature 1:\nThis feature prepares the E-commerce sales data for analysis.\nIt handles missing values and creates a new column called\n'TotalAmount' by multiplying Quantity and UnitPrice.\nThis makes it easier to analyze the total value of each transaction.\n"
