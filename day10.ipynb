# %% [markdown]
# Importing required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the Dataset

# %%
import pandas as pd
df = pd.read_csv("data.csv",encoding="latin")
print(df.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12-01-2010 08:26       2.55     17850.0  United Kingdom
# 1  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 2  12-01-2010 08:26       2.75     17850.0  United Kingdom
# 3  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 4  12-01-2010 08:26       3.39     17850.0  United Kingdom

# %% [markdown]
# Handeling the Missing Values

# %%
df["Description"] = df["Description"].fillna("Unknown")

# %%
df["CustomerID"] = df["CustomerID"].fillna("Unknown")

# %%
# Feature 1 : TotalAmount
df["TotalAmount"] = df["Quantity"]*df["UnitPrice"]

# %%
print(df.columns)
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'TotalAmount'],
#       dtype='str')

# %%
# Feature 2: Top 10 Best Selling Products

top_products = df.groupby("Description")["Quantity"].sum().sort_values(ascending=False).head(10)

print("Top 10 Best Selling Products:")
print(top_products)
# Out:
# Top 10 Best Selling Products:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847
# JUMBO BAG RED RETROSPOT               47363
# ASSORTED COLOUR BIRD ORNAMENT         36381
# POPCORN HOLDER                        36334
# PACK OF 72 RETROSPOT CAKE CASES       36039
# WHITE HANGING HEART T-LIGHT HOLDER    35317
# RABBIT NIGHT LIGHT                    30680
# MINI PAINT SET VINTAGE                26437
# PACK OF 12 LONDON TISSUES             26315
# PACK OF 60 PINK PAISLEY CAKE CASES    24753
# Name: Quantity, dtype: int64

# %% [markdown]
# Implementing third core Feature

# %%
# Core Feature 3: Top 10 Countries by Total Sales

country_sales = (
    df.groupby("Country")["TotalAmount"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(country_sales)
# Out:
# Country
# United Kingdom    8187806.364
# Netherlands        284661.540
# EIRE               263276.820
# Germany            221698.210
# France             197403.900
# Australia          137077.270
# Switzerland         56385.350
# Spain               54774.580
# Belgium             40910.960
# Sweden              36595.910
# Name: TotalAmount, dtype: float64

# %% [markdown]
# Verifying all Three Features

# %%
print("========== E-Commerce Sales Analysis ==========")

print("\nFeature 1: Total Amount")
print(df[["Quantity", "UnitPrice", "TotalAmount"]].head())

print("\nFeature 2: Top 10 Best Selling Products")
top_products = df.groupby("Description")["Quantity"].sum().sort_values(ascending=False).head(10)
print(top_products)

print("\nFeature 3: Top 10 Countries by Total Sales")
print(country_sales)

print("\nAll three features executed successfully!")
# Out:
# ========== E-Commerce Sales Analysis ==========
#
# Feature 1: Total Amount
#    Quantity  UnitPrice  TotalAmount
# 0         6       2.55        15.30
# 1         6       3.39        20.34
# 2         8       2.75        22.00
# 3         6       3.39        20.34
# 4         6       3.39        20.34
#
# Feature 2: Top 10 Best Selling Products
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847
# JUMBO BAG RED RETROSPOT               47363
# ASSORTED COLOUR BIRD ORNAMENT         36381
# POPCORN HOLDER                        36334
# PACK OF 72 RETROSPOT CAKE CASES       36039
# WHITE HANGING HEART T-LIGHT HOLDER    35317
# RABBIT NIGHT LIGHT                    30680
# MINI PAINT SET VINTAGE                26437
# PACK OF 12 LONDON TISSUES             26315
# PACK OF 60 PINK PAISLEY CAKE CASES    24753
# Name: Quantity, dtype: int64
#
# Feature 3: Top 10 Countries by Total Sales
# Country
# United Kingdom    8187806.364
# Netherlands        284661.540
# ...

# %% [markdown]
# Creating One Sample Output

# %%
print("========== SAMPLE OUTPUT ==========")

sample = df[["Description", "Quantity", "UnitPrice", "TotalAmount"]].head(5)

print(sample)
# Out:
# ========== SAMPLE OUTPUT ==========
#                            Description  Quantity  UnitPrice  TotalAmount
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6       2.55        15.30
# 1                  WHITE METAL LANTERN         6       3.39        20.34
# 2       CREAM CUPID HEARTS COAT HANGER         8       2.75        22.00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6       3.39        20.34
# 4       RED WOOLLY HOTTIE WHITE HEART.         6       3.39        20.34

# %% [markdown]
# Adding Print Statement for Debugging

# %%
print("Loading dataset...")

print("Dataset loaded successfully!")
print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))

print("Creating TotalAmount feature...")
df["TotalAmount"] = df["Quantity"] * df["UnitPrice"]
print("TotalAmount feature created successfully!")

print("Generating Top 10 Products...")
top_products = df.groupby("Description")["Quantity"].sum().sort_values(ascending=False).head(10)
print("Top 10 Products generated successfully!")

print("Generating Country Sales...")
country_sales = df.groupby("Country")["TotalAmount"].sum().sort_values(ascending=False).head(10)
print("Country Sales generated successfully!")

print("All features are working correctly!")
# Out:
# Loading dataset...
# Dataset loaded successfully!
# Number of rows: 541909
# Number of columns: 9
# Creating TotalAmount feature...
# TotalAmount feature created successfully!
# Generating Top 10 Products...
# Top 10 Products generated successfully!
# Generating Country Sales...
# Country Sales generated successfully!
# All features are working correctly!
