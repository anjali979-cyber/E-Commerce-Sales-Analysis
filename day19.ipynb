# %% [markdown]
# # Task 1
#
# ## User Testing
#
# User 1: -------
#
# Time Spent: 10 Minutes
#
# User 2: ---------
#
# Time Spent: 10 Minutes
#
# Both users tested the project successfully.

# %% [markdown]
# # Task 2
#
# ## User Observations
#
# ### User 1
# - Initially took some time to understand the project structure.
# - Needed a moment to identify the different analysis sections.
# - Successfully viewed all project outputs after running the notebook.
#
# ### User 2
# - Was confused about the purpose of the "Top 5 Customers" section at first.
# - Understood the dashboard after reading the headings.
# - Successfully completed the project without any major issues.

# %% [markdown]
# # Task 3
#
# ## Confusion Points
#
# 1. Users were initially unsure about the purpose of each analysis section.
# 2. Users needed a few moments to understand the dashboard layout.
# 3. The project contains multiple outputs, so users took time to identify each feature.
#
# ## Bugs Found
#
# - No major bugs were found during testing.
# - All features executed successfully.
# - The notebook produced the expected outputs.

# %% [markdown]
# #  Task 4
#
# ## UI Evaluation
#
# The users were asked to use the project without any explanation.
#
# Observations:
# - The section headings helped users understand the project.
# - Users were able to view the dashboard and analysis outputs independently.
# - No additional explanation was required after reading the headings.
#
# Conclusion:
# The interface is simple and understandable, but clearer section descriptions can further improve the user experience.

# %% [markdown]
# # Task 5
#
# ## Planned Improvements
#
# 1. Add more descriptive headings for each analysis section.
# 2. Improve the formatting of output tables.
# 3. Add charts to make the results easier to understand.
# 4. Organize the notebook into clearly labeled sections.
# 5. Continue improving the dashboard for better readability.
