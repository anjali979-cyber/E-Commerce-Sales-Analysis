# %% [markdown]
# # Task 1: Bug Fixes
#
# ## Bugs Fixed
#
# 1. Fixed the missing `TotalAmount` column by creating it before analysis.
# 2. Fixed KeyError issues by ensuring the required columns existed.
# 3. Fixed input validation and error handling for invalid inputs.
# 4. Verified that all three core features work correctly.
#
# Status: All bugs resolved successfully.

# %% [markdown]
# # Task 2: Code Cleanup
#
# Code Review Summary:
#
# - No unused imports found.
# - No dead or duplicate code found.
# - The notebook has been kept clean and organized.
# - Only the required code and documentation are included.

# %% [markdown]
# # Task 3: Function Documentation
#
# ## Function 1: calculate_total_amount()
# Purpose:
# - Calculates the total amount using Quantity × UnitPrice.
#
# ## Function 2: Top 10 Best Selling Products
# Purpose:
# - Finds the top 10 products based on the total quantity sold.
#
# ## Function 3: Top 10 Countries by Total Sales
# Purpose:
# - Calculates the total sales for each country and displays the top 10 countries.
