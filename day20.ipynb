# %% [markdown]
# #  Task 1
#
# ## Issues Fixed
#
# ✅ Added clearer section headings.
#
# ✅ Improved the organization of the notebook.
#
# ✅ Made the dashboard outputs easier to read.
#
# ✅ Improved the overall presentation of the project.

# %% [markdown]
# # Task 2 : Making the confusing parts clearer

# %%
print("=" * 60)
print("📊 FEATURE 1 : SALES SUMMARY DASHBOARD")
print("=" * 60)
# Out:
# ...
# 📊 FEATURE 1 : SALES SUMMARY DASHBOARD
# ...

# %%
print("=" * 60)
print("📦 FEATURE 2 : TOP 10 BEST SELLING PRODUCTS")
print("=" * 60)
# Out:
# ...
# 📦 FEATURE 2 : TOP 10 BEST SELLING PRODUCTS
# ...

# %%
print("=" * 60)
print("🌍 FEATURE 3 : TOP 10 COUNTRIES BY TOTAL SALES")
print("=" * 60)
# Out:
# ...
# 🌍 FEATURE 3 : TOP 10 COUNTRIES BY TOTAL SALES
# ...

# %%
print("=" * 60)
print("👤 FEATURE 4 : TOP 5 CUSTOMERS BY TOTAL PURCHASE")
print("=" * 60)
# Out:
# ...
# 👤 FEATURE 4 : TOP 5 CUSTOMERS BY TOTAL PURCHASE
# ...

# %% [markdown]
# # Task 3 : Instructions
#
# This notebook analyzes an E-Commerce Sales dataset.
#
# Follow these steps:
# 1. Run all cells from top to bottom.
# 2. Ensure the dataset (`data.csv`) is available.
# 3. Review each analysis section in order:
#    - Sales Summary Dashboard
#    - Top 10 Best Selling Products
#    - Top 10 Countries by Total Sales
#    - Top 5 Customers by Total Purchase

# %% [markdown]
# # Task 4 : Re-Testing Results
#
# The project was reviewed again after the improvements.
#
# Feedback:
# - The section headings are clearer.
# - The notebook is easier to navigate.
# - The outputs are easier to understand.
# - Overall readability has improved.
#
# Conclusion:
# The changes made after user testing improved the overall user experience.
