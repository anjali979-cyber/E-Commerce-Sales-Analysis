# %% [markdown]
# Importing required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the Dataset

# %%
import pandas as pd
df = pd.read_csv("data.csv",encoding="latin")
print(df.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12-01-2010 08:26       2.55     17850.0  United Kingdom
# 1  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 2  12-01-2010 08:26       2.75     17850.0  United Kingdom
# 3  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 4  12-01-2010 08:26       3.39     17850.0  United Kingdom

# %% [markdown]
# Handeling the Missing Values

# %%
df["Description"] = df["Description"].fillna("Unknown")
df["CustomerID"] = df["CustomerID"].fillna(0)

df["TotalAmount"] = df["Quantity"] * df["UnitPrice"]

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  str
#  1   StockCode    541909 non-null  str
#  2   Description  541909 non-null  str
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  str
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  float64
#  7   Country      541909 non-null  str
#  8   TotalAmount  541909 non-null  float64
# dtypes: float64(3), int64(1), str(5)
# memory usage: 37.2 MB
# None

# %%
print(df["InvoiceDate"].head())
# Out:
# 0    12-01-2010 08:26
# 1    12-01-2010 08:26
# 2    12-01-2010 08:26
# 3    12-01-2010 08:26
# 4    12-01-2010 08:26
# Name: InvoiceDate, dtype: str

# %% [markdown]
# Implementing Most Advanced Feature

# %%
print("========== SALES SUMMARY DASHBOARD ==========")

total_sales = df["TotalAmount"].sum()
total_orders = df["InvoiceNo"].nunique()
total_products = df["Quantity"].sum()
average_order_value = total_sales / total_orders

print(f"Total Sales: {total_sales:.2f}")
print(f"Total Orders: {total_orders}")
print(f"Total Products Sold: {total_products}")
print(f"Average Order Value: {average_order_value:.2f}")
# Out:
# ========== SALES SUMMARY DASHBOARD ==========
# Total Sales: 9747747.93
# Total Orders: 25900
# Total Products Sold: 5176450
# Average Order Value: 376.36

# %% [markdown]
# Libraries or APIs used

# %% [markdown]
# ## Pandas
# - Used for loading, cleaning, and analyzing the dataset.
#
# ## Matplotlib
# - Will be used in future tasks to create charts and visualizations for the dashboard.
#
# ## APIs
# - No external APIs are required for this feature.

# %% [markdown]
# ## Basic Version
#
# The basic version of the Sales Summary Dashboard has been implemented successfully.
#
# Current features:
# - Displays Total Sales
# - Displays Total Orders
# - Displays Total Products Sold
# - Displays Average Order Value
#
# The dashboard is working correctly and will be enhanced with more advanced features in the upcoming tasks.

# %% [markdown]
# Testing the Feature

# %%
print("===== Testing Sales Summary Dashboard =====")

print("Total Sales:", total_sales)
print("Total Orders:", total_orders)
print("Total Products Sold:", total_products)
print("Average Order Value:", average_order_value)

print("\n✅ Dashboard tested successfully.")
# Out:
# ===== Testing Sales Summary Dashboard =====
# Total Sales: 9747747.934
# Total Orders: 25900
# Total Products Sold: 5176450
# Average Order Value: 376.3609240926641
#
# ✅ Dashboard tested successfully.
